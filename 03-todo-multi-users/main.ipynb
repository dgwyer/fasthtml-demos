# %%
from fasthtml.common import *
from fastlite import *
from fastcore.utils import *
from fastcore.net import urlsave

# %%
db = Database("data/utodos.db")

# %%
diagram(db.tables)

# %%
db.t
# Out:
# todos, users

# %%
db.t['users'].c
# Out:
# id, name, pwd

# %%
db.t['users']
# Out:
# <Table users (id, name, pwd)>

# %%
db
# Out:
# <Database <sqlite3.Connection object at 0x7fda525af4c0>>

# %%
db.t
# Out:
# todos, users

# %%
#db.t['test'].drop()

# %%
Div('Hello')
# Out:
# div(('Hello',),{})

# %%
users = db.t.users

# %%
users()
# Out:
# [{'id': 1, 'name': 'dg', 'pwd': '1234'}]

# %%
todos = db.t.todos
todos()
# Out:
# [{'id': 1,
#   'title': 'one',
#   'done': None,
#   'name': 'dg',
#   'details': None,
#   'priority': None},
#  {'id': 2,
#   'title': 'two',
#   'done': None,
#   'name': 'dg',
#   'details': None,
#   'priority': None},
#  {'id': 3,
#   'title': '1',
#   'done': None,
#   'name': 'dg',
#   'details': None,
#   'priority': None},
#  {'id': 4,
#   'title': '2',
#   'done': None,
#   'name': 'dg',
#   'details': None,
#   'priority': None},
#  {'id': 5,
#   'title': '3',
#   'done': None,
#   'name': 'dg',
#   'details': None,
#   'priority': None},
#  {'id': 6,
#   'title': '34',
#   'done': None,
#   'name': 'dg',
#   'details': None,
#   'priority': None},
#  {'id': 7,
#   'title': '5',
#   'done': None,
#   'name': 'dg',
#   'details': None,
#   'priority': None},
#  {'id': 8,
#   'title': '5',
#   'done': None,
#   'name': 'dg',
#   'details': None,
#   'priority': None},
#  {'id': 9,
#   'title': '6',
#   'done': None,
#   'name': 'dg',
#   'details': None,
#   'priority': None},
#  {'id': 10,
#   'title': '6',
#   'done': None,
#   'name': 'dg',
#   'details': None,
#   'priority': None},
#  {'id': 11,
#   'title': '6',
#   'done': None,
#   'name': 'dg',
#   'details': None,
#   'priority': None}]
